# %%
project <- Sys.getenv('WORKSPACE_NAMESPACE')
workspace <- Sys.getenv('WORKSPACE_NAME')
bucket <- Sys.getenv('WORKSPACE_BUCKET')

# %%
library(ggplot2)
library(reshape2)

# %%
#!gsutil cp $bucket/cellranger_output_directory/bladder/harmony/cellphone/final_data_heatmap005.csv .
#df = pd.read_csv('final_data_heatmap005.csv')

# %%
system(paste0("gsutil cp -r ", bucket, "/cellranger_output_directory/bladder/harmony/cellphone/final_data_heatmap005.csv ."),intern=TRUE)
df <- read.csv('final_data_heatmap005.csv')
df
# Out:
# character(0)
#    source            source_code target             target_code lr_means
# 1  TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.990566000
# 2  TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         0.180591050
# 3  TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_3 URO3         1.695212100
# 4  TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_3 URO3         1.004782000
# 5  TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_3 URO3         0.024924628
# 6  TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_5 URO5         0.462146730
# 7  TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         0.310210940
# 8  TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         1.111619000
# 9  TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         0.534562400
# 10 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         0.511770500
# 11 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_5 URO5         1.475122200
# 12 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_5 URO5         0.463978350
# 13 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         0.219255780
# 14 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         0.291279380
# 15 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         0.430704560
# 16 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         0.148683160
# 17 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_3 URO3         2.024977400
# 18 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_3 URO3         1.237471900
# 19 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_3 URO3         0.235558120
# 20 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_5 URO5         0.968051300
# 21 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_5 URO5         0.200989650
# 22 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.611606800
# 23 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_2 URO2         1.259436000
# 24 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_1 URO1         0.104839220
# 25 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_3 URO3         0.112673730
# 26 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_5 URO5         2.205336800
# 27 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_7 URO7         0.102378890
# 28 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_1 URO1         0.240090520
# 29 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.252181050
# 30 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_1 URO1        -0.007778786
# 31 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_3 URO3         1.155000200
# 32 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_3 URO3         0.496374800
# 33 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_5 URO5         0.162120550
# 34 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1        -0.036780845
# 35 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_2 URO2         0.225316550
# 36 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_1 URO1         0.680465640
# 37 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         0.187192300
# 38 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         0.670483200
# 39 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_2 URO2         0.827635400
# 40 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         0.588933200
# 41 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         0.315617860
# 42 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.233113940
# 43 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_2 URO2         0.137225880
# 44 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_5 URO5         2.011493700
# 45 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.065949190
# 46 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.310104000
# 47 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.917686160
# 48 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.575617970
# 49 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.715143560
#    ligand_receptor  ycoord sample        sample_code response value
# 1  TIMP2 _ ITGA3     4     BLAD1002      NR1         NR        0.990566000
# 2  CXCL16 _ CXCR6    7     BLAD1029      NR2         NR        0.180591050
# 3  SPP1 _ CD44       1     BLAD1029      NR2         NR        1.695212100
# 4  APOE _ LRP8       2     BLAD1029      NR2         NR        1.004782000
# 5  IL18 _ IL18R1     8     BLAD1029      NR2         NR        0.024924628
# 6  C1QB _ C1QBP      3     BLAD1029      NR2         NR        0.462146730
# 7  CCL28 _ ACKR2     6     BLAD1077_gex  NR3         NR        0.310210940
# 8  CXCL16 _ CXCR6    7     BLAD1077_gex  NR3         NR        1.111619000
# 9  IL18 _ IL18R1     8     BLAD1077_gex  NR3         NR        0.534562400
# 10 TNFSF11 _ LGR4   10     BLAD1077_gex  NR3         NR        0.511770500
# 11 C1QB _ C1QBP      3     BLAD1077_gex  NR3         NR        1.475122200
# 12 ICAM1 _ ITGAM     5     BLAD1077_gex  NR3         NR        0.463978350
# 13 CXCL16 _ CXCR6    7     BLAD1077      NR4         NR        0.219255780
# 14 IL18 _ IL18R1     8     BLAD1077      NR4         NR        0.291279380
# 15 TNFSF11 _ LGR4   10     BLAD1077      NR4         NR        0.430704560
# 16 TNFSF4 _ TRAF2   12     BLAD1077      NR4         NR        0.148683160
# 17 SPP1 _ CD44       1     BLAD1077      NR4         NR        2.024977400
# 18 APOE _ LRP8       2     BLAD1077      NR4         NR        1.237471900
# 19 IL18 _ IL18R1     8     BLAD1077      NR4         NR        0.235558120
# 20 C1QB _ C1QBP      3     BLAD1077      NR4         NR        0.968051300
# 21 ICAM1 _ ITGAM     5     BLAD1077      NR4         NR        0.200989650
# 22 TIMP2 _ ITGA3     4     BLAD1106      NR5         NR        0.611606800
# 23 TNFSF13 _ FAS    11     BLAD1106      NR5         NR        1.259436000
# 24 IL18 _ IL18R1     8     BLAD1106      NR5         NR        0.104839220
# 25 IL18 _ IL18R1     8     BLAD1106      NR5         NR        0.112673730
# 26 C1QB _ C1QBP      3     BLAD1106      NR5         NR        2.205336800
# 27 IL18 _ IL18R1     8     BLAD1106      NR5         NR        0.102378890
# 28 IL18 _ IL18R1     8     BLAD1118      NR6         NR        0.240090520
# 29 TIMP2 _ ITGA3     4     BLAD1120      NR7         NR        0.252181050
# 30 IL18 _ IL18R1     8     BLAD1120      NR7         NR       -0.007778786
# 31 SPP1 _ CD44       1     BLAD1120      NR7         NR        1.155000200
# 32 APOE _ LRP8       2     BLAD1120      NR7         NR        0.496374800
# 33 C1QB _ C1QBP      3     BLAD1120      NR7         NR        0.162120550
# 34 TIMP2 _ ITGA3     4     BLAD1078      R1          R        -0.036780845
# 35 TNFSF8 _ TNFRSF8 13     BLAD1078      R1          R         0.225316550
# 36 IL18 _ IL18R1     8     BLAD1078      R1          R         0.680465640
# 37 CXCL16 _ CXCR6    7     BLAD1078      R1          R         0.187192300
# 38 IL18 _ IL18R1     8     BLAD1078      R1          R         0.670483200
# 39 TNFSF13 _ FAS    11     BLAD1078_gex  R2          R         0.827635400
# 40 IL18 _ IL18R1     8     BLAD1078_gex  R2          R         0.588933200
# 41 TNFSF11 _ LGR4   10     BLAD1078_gex  R2          R         0.315617860
# 42 IL1B _ IL1R1      9     BLAD1146      R3          R         0.233113940
# 43 TNFSF8 _ TNFRSF8 13     BLAD1146      R3          R         0.137225880
# 44 C1QB _ C1QBP      3     BLAD1146      R3          R         2.011493700
# 45 TIMP2 _ ITGA3     4     BLAD1149      R4          R         0.065949190
# 46 IL1B _ IL1R1      9     BLAD1149      R4          R         0.310104000
# 47 IL1B _ IL1R1      9     BLAD1157      R5          R         0.917686160
# 48 TIMP2 _ ITGA3     4     BLAD1157moccg R6          R         0.575617970
# 49 IL1B _ IL1R1      9     BLAD1157moccg R6          R         0.715143560
#    sample_source_target xcoord
# 1  NR1_TAMM1_URO1        1
# 2  NR2_TAMSPP1_URO2      2
# 3  NR2_TAMSPP1_URO3      3
# 4  NR2_TAMSPP1_URO3      3
# 5  NR2_TAMSPP1_URO3      3
# 6  NR2_TAMSPP1_URO5      4
# 7  NR3_TAMSPP1_URO2      5
# 8  NR3_TAMSPP1_URO2      5
# 9  NR3_TAMSPP1_URO2      5
# 10 NR3_TAMSPP1_URO2      5
# 11 NR3_TAMSPP1_URO5      6
# 12 NR3_TAMSPP1_URO5      6
# 13 NR4_TAMSPP1_URO2      7
# 14 NR4_TAMSPP1_URO2      7
# 15 NR4_TAMSPP1_URO2      7
# 16 NR4_TAMSPP1_URO2      7
# 17 NR4_TAMSPP1_URO3      8
# 18 NR4_TAMSPP1_URO3      8
# 19 NR4_TAMSPP1_URO3      8
# 20 NR4_TAMSPP1_URO5      9
# 21 NR4_TAMSPP1_URO5      9
# 22 NR5_TAMM1_URO1       10
# 23 NR5_TAMM1_URO2       11
# 24 NR5_TAMSPP1_URO1     12
# 25 NR5_TAMSPP1_URO3     13
# 26 NR5_TAMSPP1_URO5     14
# 27 NR5_TAMSPP1_URO7     15
# 28 NR6_TAMSPP1_URO1     16
# 29 NR7_TAMM1_URO1       17
# 30 NR7_TAMSPP1_URO1     18
# 31 NR7_TAMSPP1_URO3     19
# 32 NR7_TAMSPP1_URO3     19
# 33 NR7_TAMSPP1_URO5     20
# 34 R1_TAMM1_URO1        21
# 35 R1_TAMM1_URO2        22
# 36 R1_TAMSPP1_URO1      23
# 37 R1_TAMSPP1_URO2      24
# 38 R1_TAMSPP1_URO2      24
# 39 R2_TAMM1_URO2        25
# 40 R2_TAMSPP1_URO2      26
# 41 R2_TAMSPP1_URO2      26
# 42 R3_TAMM1_URO1        27
# 43 R3_TAMM1_URO2        28
# 44 R3_TAMSPP1_URO5      29
# 45 R4_TAMM1_URO1        30
# 46 R4_TAMM1_URO1        30
# 47 R5_TAMM1_URO1        31
# 48 R6_TAMM1_URO1        32
# 49 R6_TAMM1_URO1        32

# %%
str(df$ycoord)
# Out:
#  int [1:49] 4 7 1 2 8 3 6 7 8 10 ...

# %%
x_coord <- df$xcoord
y_coord <- df$ycoord
value <- df$value
foo <- data.frame(x_coord, y_coord, value)
foo
# Out:
#    x_coord y_coord value
# 1   1       4       0.990566000
# 2   2       7       0.180591050
# 3   3       1       1.695212100
# 4   3       2       1.004782000
# 5   3       8       0.024924628
# 6   4       3       0.462146730
# 7   5       6       0.310210940
# 8   5       7       1.111619000
# 9   5       8       0.534562400
# 10  5      10       0.511770500
# 11  6       3       1.475122200
# 12  6       5       0.463978350
# 13  7       7       0.219255780
# 14  7       8       0.291279380
# 15  7      10       0.430704560
# 16  7      12       0.148683160
# 17  8       1       2.024977400
# 18  8       2       1.237471900
# 19  8       8       0.235558120
# 20  9       3       0.968051300
# 21  9       5       0.200989650
# 22 10       4       0.611606800
# 23 11      11       1.259436000
# 24 12       8       0.104839220
# 25 13       8       0.112673730
# 26 14       3       2.205336800
# 27 15       8       0.102378890
# 28 16       8       0.240090520
# 29 17       4       0.252181050
# 30 18       8      -0.007778786
# 31 19       1       1.155000200
# 32 19       2       0.496374800
# 33 20       3       0.162120550
# 34 21       4      -0.036780845
# 35 22      13       0.225316550
# 36 23       8       0.680465640
# 37 24       7       0.187192300
# 38 24       8       0.670483200
# 39 25      11       0.827635400
# 40 26       8       0.588933200
# 41 26      10       0.315617860
# 42 27       9       0.233113940
# 43 28      13       0.137225880
# 44 29       3       2.011493700
# 45 30       4       0.065949190
# 46 30       9       0.310104000
# 47 31       9       0.917686160
# 48 32       4       0.575617970
# 49 32       9       0.715143560

# %%
matrix_data1 <- acast(foo, y_coord ~ x_coord, value.var = "value")
matrix_data1
# Out:
#    1        2         3          4         5         6         7
# 1        NA        NA 1.69521210        NA        NA        NA        NA
# 2        NA        NA 1.00478200        NA        NA        NA        NA
# 3        NA        NA         NA 0.4621467        NA 1.4751222        NA
# 4  0.990566        NA         NA        NA        NA        NA        NA
# 5        NA        NA         NA        NA        NA 0.4639783        NA
# 6        NA        NA         NA        NA 0.3102109        NA        NA
# 7        NA 0.1805911         NA        NA 1.1116190        NA 0.2192558
# 8        NA        NA 0.02492463        NA 0.5345624        NA 0.2912794
# 9        NA        NA         NA        NA        NA        NA        NA
# 10       NA        NA         NA        NA 0.5117705        NA 0.4307046
# 11       NA        NA         NA        NA        NA        NA        NA
# 12       NA        NA         NA        NA        NA        NA 0.1486832
# 13       NA        NA         NA        NA        NA        NA        NA
#    8         9         10        ⋯ 23        24        25        26
# 1  2.0249774        NA        NA ⋯        NA        NA        NA        NA
# 2  1.2374719        NA        NA ⋯        NA        NA        NA        NA
# 3         NA 0.9680513        NA ⋯        NA        NA        NA        NA
# 4         NA        NA 0.6116068 ⋯        NA        NA        NA        NA
# 5         NA 0.2009896        NA ⋯        NA        NA        NA        NA
# 6         NA        NA        NA ⋯        NA        NA        NA        NA
# 7         NA        NA        NA ⋯        NA 0.1871923        NA        NA
# 8  0.2355581        NA        NA ⋯ 0.6804656 0.6704832        NA 0.5889332
# 9         NA        NA        NA ⋯        NA        NA        NA        NA
# 10        NA        NA        NA ⋯        NA        NA        NA 0.3156179
# 11        NA        NA        NA ⋯        NA        NA 0.8276354        NA
# 12        NA        NA        NA ⋯        NA        NA        NA        NA
# 13        NA        NA        NA ⋯        NA        NA        NA        NA
#    27        28        29       30         31        32
# 1         NA        NA       NA         NA        NA        NA
# 2         NA        NA       NA         NA        NA        NA
# 3         NA        NA 2.011494         NA        NA        NA
# 4         NA        NA       NA 0.06594919        NA 0.5756180
# 5         NA        NA       NA         NA        NA        NA
# 6         NA        NA       NA         NA        NA        NA
# 7         NA        NA       NA         NA        NA        NA
# 8         NA        NA       NA         NA        NA        NA
# 9  0.2331139        NA       NA 0.31010400 0.9176862 0.7151436
# 10        NA        NA       NA         NA        NA        NA
# 11        NA        NA       NA         NA        NA        NA
# 12        NA        NA       NA         NA        NA        NA
# 13        NA 0.1372259       NA         NA        NA        NA

# %%
ggplot(melt(matrix_data1), aes(Var2, Var1, fill = value)) +
  geom_tile() +
  scale_fill_gradient(low = "white", high = "red") +
  labs(x = "X Coordinate", y = "Y Coordinate", title = "CellphoneDB result HeatMap")
# Out:
# plot without title

# %%
q<- ggplot(df, aes(x = sample_source_target, y = ycoord)) +
  geom_tile(aes(fill = lr_means), colour = "white") +
  scale_fill_gradient(low = "#1E90FF", high = "red") +
  theme_classic() #theme_void() #theme_dark() #



qq<- ggplot(df, aes(x = sample_source_target, y = ligand_receptor)) +
  geom_tile(aes(fill = lr_means), colour = "white") +
  scale_fill_gradient(low = "#1E90FF", high = "red") +
  theme_classic() #theme_void() #theme_dark() #

q + theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
qq + theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# plot without title
# plot without title

# %%
df
# Out:
#    source            source_code target             target_code lr_means
# 1  TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1        1.49721620
# 2  TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1        0.99056600
# 3  TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2        0.18059105
# 4  TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2        0.40168786
# 5  TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2        0.24190952
# 6  TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_3 URO3        1.00478200
# 7  TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_3 URO3        0.02492463
# 8  TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_3 URO3        0.07021663
# 9  TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_3 URO3        1.69521210
# 10 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_5 URO5        0.46214673
# 11 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2        0.31021094
# 12 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2        1.11161900
# 13 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2        0.53456240
# 14 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2        0.42220310
# 15 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2        1.68390260
# 16 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2        0.51177050
# 17 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_5 URO5        1.47512220
# 18 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_5 URO5        0.46397835
# 19 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_5 URO5        0.38957852
# 20 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2        0.21925578
# 21 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2        0.29127938
# 22 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2        0.11122323
# 23 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2        0.34657510
# 24 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2        0.43070456
# 25 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2        0.14868316
# 26 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_3 URO3        1.23747190
# 27 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_3 URO3        0.23555812
# 28 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_3 URO3        2.02497740
# 29 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_5 URO5        0.96805130
# 30 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_5 URO5        0.20098965
# ⋮  ⋮                 ⋮           ⋮                  ⋮           ⋮
# 59 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         0.37967970
# 60 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         1.50719060
# 61 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.90367390
# 62 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_2 URO2         0.82763540
# 63 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_4 URO4         0.66127825
# 64 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_4 URO4         0.70617310
# 65 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         0.58893320
# 66 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         1.19329940
# 67 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         0.31561786
# 68 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1        -0.06825001
# 69 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.23311394
# 70 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         1.03698090
# 71 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.90726995
# 72 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_2 URO2         0.13722588
# 73 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_2 URO2         0.45555484
# 74 TAM PARP14+ SPP1+ TAMSPP1     Urothelial Usage_5 URO5         2.01149370
# 75 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.06562263
# 76 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1        -0.10475780
# 77 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.31010400
# 78 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.80354880
# 79 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         1.07472370
# 80 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.06594919
# 81 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.91768616
# 82 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.76729280
# 83 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.89999950
# 84 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1        -0.02166420
# 85 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.71514356
# 86 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.39843583
# 87 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         1.14114480
# 88 TAM M1 HLA-DPB1+  TAMM1       Urothelial Usage_1 URO1         0.57561797
#    ligand_receptor  ycoord sample        sample_code response value
# 1  JAML _ CXADR     13     BLAD1002      NR1         NR       1.49721620
# 2  TIMP2 _ ITGA3    20     BLAD1002      NR1         NR       0.99056600
# 3  CXCL16 _ CXCR6    6     BLAD1029      NR2         NR       0.18059105
# 4  LILRB4 _ LAIR1   14     BLAD1029      NR2         NR       0.40168786
# 5  TIGIT _ NECTIN2  19     BLAD1029      NR2         NR       0.24190952
# 6  APOE _ LRP8       1     BLAD1029      NR2         NR       1.00478200
# 7  IL18 _ IL18R1    10     BLAD1029      NR2         NR       0.02492463
# 8  IL6 _ IL6R       12     BLAD1029      NR2         NR       0.07021663
# 9  SPP1 _ CD44      16     BLAD1029      NR2         NR       1.69521210
# 10 C1QB _ C1QBP      4     BLAD1029      NR2         NR       0.46214673
# 11 CCL28 _ ACKR2     5     BLAD1077_gex  NR3         NR       0.31021094
# 12 CXCL16 _ CXCR6    6     BLAD1077_gex  NR3         NR       1.11161900
# 13 IL18 _ IL18R1    10     BLAD1077_gex  NR3         NR       0.53456240
# 14 IL6 _ IL6R       12     BLAD1077_gex  NR3         NR       0.42220310
# 15 LILRB4 _ LAIR1   14     BLAD1077_gex  NR3         NR       1.68390260
# 16 TNFSF11 _ LGR4   21     BLAD1077_gex  NR3         NR       0.51177050
# 17 C1QB _ C1QBP      4     BLAD1077_gex  NR3         NR       1.47512220
# 18 ICAM1 _ ITGAM     9     BLAD1077_gex  NR3         NR       0.46397835
# 19 IL6 _ IL6R       12     BLAD1077_gex  NR3         NR       0.38957852
# 20 CXCL16 _ CXCR6    6     BLAD1077      NR4         NR       0.21925578
# 21 IL18 _ IL18R1    10     BLAD1077      NR4         NR       0.29127938
# 22 IL6 _ IL6R       12     BLAD1077      NR4         NR       0.11122323
# 23 LILRB4 _ LAIR1   14     BLAD1077      NR4         NR       0.34657510
# 24 TNFSF11 _ LGR4   21     BLAD1077      NR4         NR       0.43070456
# 25 TNFSF4 _ TRAF2   23     BLAD1077      NR4         NR       0.14868316
# 26 APOE _ LRP8       1     BLAD1077      NR4         NR       1.23747190
# 27 IL18 _ IL18R1    10     BLAD1077      NR4         NR       0.23555812
# 28 SPP1 _ CD44      16     BLAD1077      NR4         NR       2.02497740
# 29 C1QB _ C1QBP      4     BLAD1077      NR4         NR       0.96805130
# 30 ICAM1 _ ITGAM     9     BLAD1077      NR4         NR       0.20098965
# ⋮  ⋮                ⋮      ⋮             ⋮           ⋮        ⋮
# 59 TIGIT _ NECTIN2  19     BLAD1078      R1          R         0.37967970
# 60 JAML _ CXADR     13     BLAD1078_gex  R2          R         1.50719060
# 61 THBS1 _ ITGA6    18     BLAD1078_gex  R2          R         0.90367390
# 62 TNFSF13 _ FAS    22     BLAD1078_gex  R2          R         0.82763540
# 63 BMP1 _ BMPR1B     2     BLAD1078_gex  R2          R         0.66127825
# 64 BMP2 _ BMPR1B     3     BLAD1078_gex  R2          R         0.70617310
# 65 IL18 _ IL18R1    10     BLAD1078_gex  R2          R         0.58893320
# 66 LILRB4 _ LAIR1   14     BLAD1078_gex  R2          R         1.19329940
# 67 TNFSF11 _ LGR4   21     BLAD1078_gex  R2          R         0.31561786
# 68 HLA-B _ LILRB1    8     BLAD1146      R3          R        -0.06825001
# 69 IL1B _ IL1R1     11     BLAD1146      R3          R         0.23311394
# 70 JAML _ CXADR     13     BLAD1146      R3          R         1.03698090
# 71 THBS1 _ ITGA6    18     BLAD1146      R3          R         0.90726995
# 72 TNFSF8 _ TNFRSF8 24     BLAD1146      R3          R         0.13722588
# 73 LILRB4 _ LAIR1   14     BLAD1146      R3          R         0.45555484
# 74 C1QB _ C1QBP      4     BLAD1146      R3          R         2.01149370
# 75 FN1 _ ITGB6       7     BLAD1149      R4          R         0.06562263
# 76 HLA-B _ LILRB1    8     BLAD1149      R4          R        -0.10475780
# 77 IL1B _ IL1R1     11     BLAD1149      R4          R         0.31010400
# 78 JAML _ CXADR     13     BLAD1149      R4          R         0.80354880
# 79 THBS1 _ ITGA6    18     BLAD1149      R4          R         1.07472370
# 80 TIMP2 _ ITGA3    20     BLAD1149      R4          R         0.06594919
# 81 IL1B _ IL1R1     11     BLAD1157      R5          R         0.91768616
# 82 JAML _ CXADR     13     BLAD1157      R5          R         0.76729280
# 83 THBS1 _ ITGA6    18     BLAD1157      R5          R         0.89999950
# 84 HLA-B _ LILRB1    8     BLAD1157moccg R6          R        -0.02166420
# 85 IL1B _ IL1R1     11     BLAD1157moccg R6          R         0.71514356
# 86 JAML _ CXADR     13     BLAD1157moccg R6          R         0.39843583
# 87 THBS1 _ ITGA6    18     BLAD1157moccg R6          R         1.14114480
# 88 TIMP2 _ ITGA3    20     BLAD1157moccg R6          R         0.57561797
#    sample_source_target xcoord
# 1  NR1_TAMM1_URO1       1
# 2  NR1_TAMM1_URO1       1
# 3  NR2_TAMSPP1_URO2     2
# 4  NR2_TAMSPP1_URO2     2
# 5  NR2_TAMSPP1_URO2     2
# 6  NR2_TAMSPP1_URO3     3
# 7  NR2_TAMSPP1_URO3     3
# 8  NR2_TAMSPP1_URO3     3
# 9  NR2_TAMSPP1_URO3     3
# 10 NR2_TAMSPP1_URO5     4
# 11 NR3_TAMSPP1_URO2     5
# 12 NR3_TAMSPP1_URO2     5
# 13 NR3_TAMSPP1_URO2     5
# 14 NR3_TAMSPP1_URO2     5
# 15 NR3_TAMSPP1_URO2     5
# 16 NR3_TAMSPP1_URO2     5
# 17 NR3_TAMSPP1_URO5     6
# 18 NR3_TAMSPP1_URO5     6
# 19 NR3_TAMSPP1_URO5     6
# 20 NR4_TAMSPP1_URO2     7
# 21 NR4_TAMSPP1_URO2     7
# 22 NR4_TAMSPP1_URO2     7
# 23 NR4_TAMSPP1_URO2     7
# 24 NR4_TAMSPP1_URO2     7
# 25 NR4_TAMSPP1_URO2     7
# 26 NR4_TAMSPP1_URO3     8
# 27 NR4_TAMSPP1_URO3     8
# 28 NR4_TAMSPP1_URO3     8
# 29 NR4_TAMSPP1_URO5     9
# 30 NR4_TAMSPP1_URO5     9
# ⋮  ⋮                    ⋮
# 59 R1_TAMSPP1_URO2      26
# 60 R2_TAMM1_URO1        27
# 61 R2_TAMM1_URO1        27
# 62 R2_TAMM1_URO2        28
# 63 R2_TAMM1_URO4        29
# 64 R2_TAMM1_URO4        29
# 65 R2_TAMSPP1_URO2      30
# 66 R2_TAMSPP1_URO2      30
# 67 R2_TAMSPP1_URO2      30
# 68 R3_TAMM1_URO1        31
# 69 R3_TAMM1_URO1        31
# 70 R3_TAMM1_URO1        31
# 71 R3_TAMM1_URO1        31
# 72 R3_TAMM1_URO2        32
# 73 R3_TAMSPP1_URO2      33
# 74 R3_TAMSPP1_URO5      34
# 75 R4_TAMM1_URO1        35
# 76 R4_TAMM1_URO1        35
# 77 R4_TAMM1_URO1        35
# 78 R4_TAMM1_URO1        35
# 79 R4_TAMM1_URO1        35
# 80 R4_TAMM1_URO1        35
# 81 R5_TAMM1_URO1        36
# 82 R5_TAMM1_URO1        36
# 83 R5_TAMM1_URO1        36
# 84 R6_TAMM1_URO1        37
# 85 R6_TAMM1_URO1        37
# 86 R6_TAMM1_URO1        37
# 87 R6_TAMM1_URO1        37
# 88 R6_TAMM1_URO1        37

# %%
q<- ggplot(df, aes(x = sample_source_target, y = ycoord)) +
  geom_tile(aes(fill = lr_means), colour = "white") +
  scale_fill_gradient(low = "white", high = "red") +
  theme_minimal()

q + theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %%
q<- ggplot(df, aes(x = target, y = ligand_receptor)) +
  geom_tile(aes(fill = lr_means), colour = "white") +
  scale_fill_gradient(low = "white", high = "red") +
  theme_minimal()

q + theme(axis.text.x = element_text(angle = 45, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %%
q<- ggplot(df, aes(x = sample_code, y = ycoord)) +
  geom_tile(aes(fill = lr_means), colour = "white") +
  scale_fill_gradient(low = "#79baec", high = "red") +
  theme_classic() 

q + theme(axis.text.x = element_text(angle = 45, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %%
q<- ggplot(df, aes(x = sample_code, y = ycoord)) +
  geom_tile(aes(fill = lr_means), colour = "white") +
  scale_fill_gradient(low = "#bdd5e7", high = "red") +
  theme_classic() 

q + theme(axis.text.x = element_text(angle = 45, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %%
q<- ggplot(df, aes(x = sample_code, y = ycoord)) +
  geom_tile(aes(fill = lr_means), colour = "white") +
  scale_fill_gradient(low = "#bdd5e7", high = "#1034a6") +
  theme_classic() 

q + theme(axis.text.x = element_text(angle = 45, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %%
q<- ggplot(df, aes(x = sample_code, y = ycoord)) +
  geom_tile(aes(fill = lr_means), colour = "white") +
 #scale_fill_gradient2(low = "#7382df", mid= "#ffsa10", high="red", midpoint = 0.75, na.value = "grey50")+
 #v7 #scale_fill_gradient2(low = "#fe7a15", mid="#6788f0" , high="#000395", midpoint = 0.5, na.value = "grey50")+
 scale_fill_gradient2(low = "#ff7b89", mid="#6f5f90" , high="#000395", midpoint = 1, na.value = "grey50")+

#scale_fill_gradient(low = "#f26ba6", high="#6485ee",na.value = "grey50")+
  theme_classic() 

q + theme(axis.text.x = element_text(angle = 45, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %%
q<- ggplot(df, aes(x = sample_code, y = ycoord)) +
  geom_tile(aes(fill = lr_means), colour = "white") +
 scale_fill_gradient2(low = "#ff9190", mid="#5e72eb" , high="#000395", midpoint = 1.3, na.value = "grey50")+
 #scale_fill_gradient(low = "#ff9190",  high="#5e72eb")+

  theme_classic() 

q + theme(axis.text.x = element_text(angle = 45, vjust = 0.5, hjust=1))
# Out:
# plot without title

# %%
ggplot(df, aes(x = response, y = ligand_receptor)) +
  geom_tile(aes(fill = lr_means), colour = "white") +
  scale_fill_gradient(low = "white", high = "red") +
  theme_minimal()

#q + theme(axis.text.x = element_text(angle = 45, vjust = 0.5, hjust=1))


ggplot(df, aes(x = source, y = ligand_receptor)) +
  geom_tile(aes(fill = value), colour = "white") +
  scale_fill_gradient(low = "white", high = "red") +
  theme_minimal()
# Out:
# plot without title
# plot without title
